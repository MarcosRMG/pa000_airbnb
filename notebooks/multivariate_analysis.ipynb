# %% [markdown]
# # Dev Env

# %% [markdown]
# ## Imports

# %%
library(tidyverse)
# Out:
# ── Attaching packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
#
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ## Settings

# %%
# Graph size
options(repr.plot.width = 18, repr.plot.height = 10)

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# ## Input Data

# %%
df = read_csv('../data/processed/feature_engineering.csv')
# Out:
# Rows: 207386 Columns: 34
#
# ── Column specification ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (11): id, gender, signup_method, language, affiliate_channel, affiliate...
# dbl  (20): age, signup_flow, days_first_active_to_booking, days_first_active...
# date  (3): date_account_created, timestamp_first_active, date_first_booking
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
head(df)
# Out:
#   id         date_account_created timestamp_first_active date_first_booking
# 1 gxn3p5htnn 2010-06-28           2009-03-19             2010-07-01
# 2 820tgsjxq7 2011-05-25           2009-05-23             2011-05-28
# 3 4ft3gnwmtx 2010-09-28           2009-06-09             2010-08-02
# 4 bjjt8pjhuk 2011-12-05           2009-10-31             2012-09-08
# 5 87mebub9p4 2010-09-14           2009-12-08             2010-02-18
# 6 osr2jwljor 2010-01-01           2010-01-01             2010-01-02
#   gender    age signup_method signup_flow language affiliate_channel ⋯
# 1 -unknown- 34  facebook      0           en       direct            ⋯
# 2 MALE      38  facebook      0           en       seo               ⋯
# 3 FEMALE    56  basic         3           en       direct            ⋯
# 4 FEMALE    42  facebook      0           en       direct            ⋯
# 5 -unknown- 41  basic         0           en       direct            ⋯
# ...

# %%
colnames(df)
# Out:
#  [1] "id"
#  [2] "date_account_created"
#  [3] "timestamp_first_active"
#  [4] "date_first_booking"
#  [5] "gender"
#  [6] "age"
#  [7] "signup_method"
#  [8] "signup_flow"
#  [9] "language"
# [10] "affiliate_channel"
# [11] "affiliate_provider"
# [12] "first_affiliate_tracked"
# [13] "signup_app"
# [14] "first_device_type"
# [15] "first_browser"
# [16] "country_destination"
# [17] "days_first_active_to_booking"
# [18] "days_first_active_to_account_created"
# [19] "days_account_created_first_booking"
# [20] "year_first_active"
# [21] "month_first_active"
# [22] "day_first_active"
# [23] "day_of_week_first_active"
# [24] "week_of_year_first_active"
# [25] "year_first_booking"
# [26] "month_first_booking"
# [27] "day_first_booking"
# [28] "day_of_week_first_booking"
# [29] "week_of_year_first_booking"
# [30] "year_account_created"
# [31] "month_account_created"
# [32] "day_account_created"
# [33] "day_of_week_account_created"
# [34] "week_of_year_account_created"

# %%
unique(df$affiliate_provider)
# Out:
#  [1] "direct"              "google"              "other"
#  [4] "craigslist"          "facebook"            "vast"
#  [7] "bing"                "meetup"              "facebook-open-graph"
# [10] "email-marketing"     "yahoo"               "padmapper"
# [13] "gsp"                 "wayn"                "naver"
# [16] "baidu"               "yandex"              "daum"

# %% [markdown]
# ## Dataviz

# %%
# Age between 18 to 50
ggplot(data = df[df$age < 50 & df$age > 18, ]) +
    geom_boxplot(mapping = aes(x = gender, y = age, colour = signup_method))
# Out:
# plot without title

# %% [markdown]
#     User that don't identify the gender use basic and facebook signup method

# %%
# Age between 18 to 50
ggplot(data = df[df$age < 50 & df$age > 18, ]) +
    geom_boxplot(mapping = aes(x = country_destination, y = age, colour = signup_method))
# Out:
# plot without title

# %%
# Age between 18 to 50
ggplot(data = df[df$age < 50 & df$age > 18, ]) +
    geom_boxplot(mapping = aes(x = country_destination, y = age, colour = signup_app))
# Out:
# plot without title

# %%
# Age between 18 to 50
ggplot(data = df[df$age < 50 & df$age > 18, ]) +
    geom_boxplot(mapping = aes(x = country_destination, y = age, colour = gender))
# Out:
# plot without title
