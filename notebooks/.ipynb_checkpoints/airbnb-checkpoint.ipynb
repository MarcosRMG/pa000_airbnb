# %% [markdown]
# # Business Challange

# %% [markdown]
# ## Planning IoT

# %% [markdown]
# ### Input

# %% [markdown]
#     1. Goal
#
#         1.1 Anticipate the first destination the new user will book
#
#     2. Data
#         2.1 age_gender
#         2.2 countries
#         2.3 sessions
#         2.4 test_users
#         2.5 train_users

# %% [markdown]
# ### Output

# %% [markdown]
#     1. Report Analysis about user behavior
#     2. Machine Learning Model to predict users booking

# %% [markdown]
# ### Tasks

# %% [markdown]
#     1. Define the best model with prediction
#     2. Store the informaiton with prediction in a table
#     3. Provide an API to access predictions

# %% [markdown]
# # Dev Env

# %% [markdown]
# ## Imports

# %%
# Data Manipulation
import numpy  as np
import pandas as pd
import pickle

# Data Visualization
import seaborn           as sns
import matplotlib.pyplot as plt

# Machine Learning
import random
from keras                   import models
from keras                   import layers
from sklearn.metrics         import accuracy_score
from scikitplot.metrics      import plot_confusion_matrix
from sklearn.preprocessing   import OneHotEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Settings

# %%
# Random seed
seed = random.seed(24)
plt.rcParams['figure.figsize'] = [12,8]

# %% [markdown]
# ## Data Raw

# %%
# age_gender
age_gender = pd.read_csv('../data/age_gender_bkts.csv')

# countries
countries = pd.read_csv('../data/countries.csv')

# sessions
sessions = pd.read_csv('../data/sessions.csv')

# train users
train_users = pd.read_csv('../data/train_users_2.csv')

# %%
age_gender.shape
# Out:
# (420, 5)

# %%
age_gender.head(3)
# Out:
#   age_bucket country_destination gender  population_in_thousands    year
# 0       100+                  AU   male                      1.0  2015.0
# 1      95-99                  AU   male                      9.0  2015.0
# 2      90-94                  AU   male                     47.0  2015.0

# %%
countries.shape
# Out:
# (10, 7)

# %%
countries.head(3)
# Out:
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# 1        9984670.0                   eng                           0.00
# 2         357022.0                   deu                          72.61

# %%
sessions.shape
# Out:
# (10567737, 6)

# %%
sessions.head(3)
# Out:
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0

# %%
train_users.shape
# Out:
# (213451, 16)

# %%
train_users.head(3)
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US

# %% [markdown]
# # Data Description

# %% [markdown]
# ## Data Input

# %%
df1 = train_users.copy()
df1.head(3)
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US

# %% [markdown]
# ## Data Types

# %%
df1.dtypes
# Out:
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object

# %%
# Change
# date_account_created        datetime
# date_first_booking          datetime
# age                         int
# signup_flow                 int64

# %% [markdown]
# ## Check NaN

# %%
df1.isna().sum()
# Out:
# id                              0
# date_account_created            0
# timestamp_first_active          0
# date_first_booking         124543
# gender                          0
# age                         87990
# signup_method                   0
# signup_flow                     0
# language                        0
# affiliate_channel               0
# affiliate_provider              0
# first_affiliate_tracked      6065
# signup_app                      0
# first_device_type               0
# first_browser                   0
# country_destination             0
# dtype: int64

# %% [markdown]
# ## Fill NaN

# %%
df1.dropna(inplace=True)

# %% [markdown]
# ## Change Types

# %%
# Change
# date_account_created        datetime
df1['date_account_created'] = pd.to_datetime(df1['date_account_created'])

# date_first_booking          datetime
df1['date_first_booking'] = pd.to_datetime(df1['date_first_booking'])

# timestamp_first_active
df1['timestamp_first_active'] = pd.to_datetime(df1['timestamp_first_active'], format='%Y%m%d%H%M%S')

# age                         int
df1['age'] = df1['age'].astype('int64')
                                           
# signup_flow                 int64
df1['signup_flow'] = df1['signup_flow'].astype('int64')

# %% [markdown]
# ## Check Balanced Data

# %%
round(df1['country_destination'].value_counts(normalize=True) * 100, 1)
# Out:
# US       70.9
# other    11.1
# FR        5.4
# IT        3.0
# GB        2.6
# ES        2.5
# CA        1.6
# DE        1.2
# NL        0.9
# AU        0.6
# PT        0.2
# Name: country_destination, dtype: float64

# %% [markdown]
# ## Data Output

# %%
df1.to_csv('../data/processed/df1.csv', index=False)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # EDA

# %% [markdown]
# # Data Filter

# %% [markdown]
# ## Data Input

# %%
df6 = pd.read_csv('../data/processed/df1.csv')

# %% [markdown]
# ## Cols drop

# %%
cols_drop = ['date_account_created', 'timestamp_first_active', 'date_first_booking']
df6.drop(columns=cols_drop, inplace=True)

# %% [markdown]
# ## Data Output

# %%
df6.to_csv('../data/processed/df_filter.csv', index=False)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Input

# %%
df7 = pd.read_csv('../data/processed/df_filter.csv')

# %%
# Dummies
to_dummies = df7.drop(columns=['id', 'age', 'signup_flow', 'country_destination'])
no_dummies = df7[['id', 'age', 'signup_flow', 'country_destination']]

# %%
# Get dummies
to_dummies = pd.get_dummies(to_dummies)

# Concat data
df7_dummies = pd.concat([no_dummies, to_dummies], axis=1)

# %% [markdown]
# ## Split Data

# %%
X = df7_dummies.drop(columns='country_destination')
y = df7_dummies['country_destination']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

# %% [markdown]
# ## Encoder

# %%
# ======================================OneHotEncoder======================================
# Train
ohe = OneHotEncoder()
y_train = ohe.fit_transform(y_train.values.reshape(-1, 1)).toarray()
pickle.dump(ohe, open('../data/models/one_hot_country_destination.pkl', 'wb'))

# %% [markdown]
# ## Data Output

# %%
# X data
X_train.to_csv('../data/processed/X_train.csv', index=False)
X_test.to_csv('../data/processed/X_test.csv', index=False)

# Y data
pd.DataFrame(y_train).to_csv('../data/processed/y_train.csv', index=False) 
y_test.to_csv('../data/processed/y_test.csv', index=False)

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Data Input

# %% [markdown]
# # ML Model

# %% [markdown]
# ## Data Input

# %%
x_train = pd.read_csv('../data/processed/X_train.csv').drop(columns='id')
x_test  = pd.read_csv('../data/processed/X_test.csv').drop(columns='id')

y_train = pd.read_csv('../data/processed/y_train.csv').values
y_test = pd.read_csv('../data/processed/y_test.csv')

ohe = pickle.load(open('../data/models/one_hot_country_destination.pkl', 'rb'))

# %% [markdown]
# ## Neural Network

# %%
# Model definition
model = models.Sequential()
model.add(layers.Dense(128, input_dim=x_train.shape[1], activation='relu'))
model.add(layers.Dense(11, activation='softmax'))

# model compile
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train
model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 1705/1705 [==============================] - 1s 705us/step - loss: 1.3223 - accuracy: 0.7064
# Epoch 2/100
# 1705/1705 [==============================] - 1s 701us/step - loss: 1.2464 - accuracy: 0.7085
# Epoch 3/100
# 1705/1705 [==============================] - 1s 699us/step - loss: 1.2233 - accuracy: 0.7090
# Epoch 4/100
# 1705/1705 [==============================] - 1s 706us/step - loss: 1.2180 - accuracy: 0.7090
# Epoch 5/100
# 1705/1705 [==============================] - 1s 704us/step - loss: 1.1942 - accuracy: 0.7091
# Epoch 6/100
# 1705/1705 [==============================] - 1s 708us/step - loss: 1.1806 - accuracy: 0.7091
# Epoch 7/100
# 1705/1705 [==============================] - 1s 707us/step - loss: 1.1647 - accuracy: 0.7091
# Epoch 8/100
# 1705/1705 [==============================] - 1s 708us/step - loss: 1.1485 - accuracy: 0.7093
# Epoch 9/100
# 1705/1705 [==============================] - 1s 826us/step - loss: 1.1405 - accuracy: 0.7094
# Epoch 10/100
# 1705/1705 [==============================] - 1s 866us/step - loss: 1.1366 - accuracy: 0.7095
# Epoch 11/100
# 1705/1705 [==============================] - 1s 838us/step - loss: 1.1332 - accuracy: 0.7096
# Epoch 12/100
# 1705/1705 [==============================] - 1s 828us/step - loss: 1.1307 - accuracy: 0.7102
# Epoch 13/100
# 1705/1705 [==============================] - 1s 834us/step - loss: 1.1300 - accuracy: 0.7101
# Epoch 14/100
# 1705/1705 [==============================] - 1s 844us/step - loss: 1.1279 - accuracy: 0.7103
# Epoch 15/100
# 1705/1705 [==============================] - 1s 826us/step - loss: 1.1269 - accuracy: 0.7102
# Epoch 16/100
# Epoch 76/100
# 1705/1705 [==============================] - 1s 745us/step - loss: 1.0967 - accuracy: 0.7123
# Epoch 77/100
# 1705/1705 [==============================] - 1s 721us/step - loss: 1.0963 - accuracy: 0.7125
# Epoch 78/100
# 1705/1705 [==============================] - 1s 653us/step - loss: 1.0963 - accuracy: 0.7127
# Epoch 79/100
# 1705/1705 [==============================] - 1s 645us/step - loss: 1.0954 - accuracy: 0.7128
# Epoch 80/100
# 1705/1705 [==============================] - 1s 643us/step - loss: 1.0950 - accuracy: 0.7124
# Epoch 81/100
# 1705/1705 [==============================] - 1s 640us/step - loss: 1.0953 - accuracy: 0.7126
# Epoch 82/100
# 1705/1705 [==============================] - 1s 638us/step - loss: 1.0947 - accuracy: 0.7126
# Epoch 83/100
# 1705/1705 [==============================] - 1s 641us/step - loss: 1.0947 - accuracy: 0.7128
# Epoch 84/100
# 1705/1705 [==============================] - 1s 641us/step - loss: 1.0944 - accuracy: 0.7127
# Epoch 85/100
# 1705/1705 [==============================] - 1s 639us/step - loss: 1.0941 - accuracy: 0.7126
# Epoch 86/100
# 1705/1705 [==============================] - 1s 639us/step - loss: 1.0947 - accuracy: 0.7128
# Epoch 87/100
# 1705/1705 [==============================] - 1s 637us/step - loss: 1.0935 - accuracy: 0.7130
# Epoch 88/100
# 1705/1705 [==============================] - 1s 639us/step - loss: 1.0928 - accuracy: 0.7128
# Epoch 89/100
# 1705/1705 [==============================] - 1s 637us/step - loss: 1.0936 - accuracy: 0.7130
# Epoch 90/100
# 1705/1705 [==============================] - 1s 635us/step - loss: 1.0930 - accuracy: 0.7128
# Epoch 91/100
# 1705/1705 [==============================] - 1s 635us/step - loss: 1.0930 - accuracy: 0.7128
# Epoch 92/100
# 1705/1705 [==============================] - 1s 636us/step - loss: 1.0925 - accuracy: 0.7127
# Epoch 93/100
# 1705/1705 [==============================] - 1s 636us/step - loss: 1.0925 - accuracy: 0.7129
# Epoch 94/100
# 1705/1705 [==============================] - 1s 638us/step - loss: 1.0916 - accuracy: 0.7131
# Epoch 95/100
# 1705/1705 [==============================] - 1s 634us/step - loss: 1.0916 - accuracy: 0.7125
# Epoch 96/100
# 1705/1705 [==============================] - 1s 639us/step - loss: 1.0915 - accuracy: 0.7129
# Epoch 97/100
# 1705/1705 [==============================] - 1s 633us/step - loss: 1.0913 - accuracy: 0.7133
# Epoch 98/100
# 1705/1705 [==============================] - 1s 635us/step - loss: 1.0913 - accuracy: 0.7131
# Epoch 99/100
# 1705/1705 [==============================] - 1s 639us/step - loss: 1.0913 - accuracy: 0.7135
# Epoch 100/100
# 1705/1705 [==============================] - 1s 638us/step - loss: 1.0909 - accuracy: 0.7131

# %%
# Prediction
pred_nn = model.predict(x_test)

# Invert prediction
yhat_nn = ohe.inverse_transform(pred_nn).flatten()

# Prediction prepare
y_test_nn = y_test.to_numpy().flatten()

# %%
# Accuracy
print(f'Accuracy: {round(accuracy_score(y_test_nn, yhat_nn), 1) * 100}%')

# Confusion Matrix
plot_confusion_matrix(y_test_nn, yhat_nn)
plt.show()
# Out:
# Accuracy: 70.0%

# %% [markdown]
# # Model Performance

# %% [markdown]
# # Deploy
